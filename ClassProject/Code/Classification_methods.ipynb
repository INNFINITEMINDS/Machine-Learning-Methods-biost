# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import random

import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier

# %%
# load the data
df_rna = pd.read_hdf("rna_scaled.hdf")
df_dnase = pd.read_hdf("dnase_scaled.hdf")
df_gene_info = pd.read_hdf("df_gene_info.hdf")

# %%
# a find gene list function that accept a Dnase position, a df_RNA file, a df_gene_info data frame, and a distance number, and then
# return the list of gene names for prediction
def find_gene_list(dnase_position, df_gene_info, distance):
    dnase_ls = dnase_position.split("-")
    chr_id = dnase_ls[0]
    chr_start = int(dnase_ls[1])
    chr_end = int(dnase_ls[2])
    
    # define the interval for gene selection
    gene_chr = chr_id.replace("chr", "")
    gene_start = chr_start - distance
    gene_end = chr_end + distance
    #print(gene_chr, gene_start, gene_end)
    # find the gene list for the gene interval
    df_gene_filter = df_gene_info[df_gene_info["chr"] == gene_chr]
    df_gene_filter = df_gene_filter[df_gene_filter["start"] >= gene_start]
    df_gene_filter = df_gene_filter[df_gene_filter["start"] <= gene_end]
    gene_ls = df_gene_filter.index
    return(gene_ls)

# %%
#take first 500 columns as samples
samples = df_dnase[list(range(500))]
samples
# Out:
# position                                          chr1-100009480-100010443  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.000000
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  1.000000
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.000000
# Breast_vHMEC                                                      0.838002
# H1_Derived_Mesenchymal_Stem_Cells                                 0.680418
# Fetal_Intestine_Small                                             0.000000
# Fetal_Intestine_Large                                             0.000000
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.000000
# Psoas_Muscle                                                      0.000000
# Gastric                                                           0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.658038
# Pancreas                                                          0.000000
# Mobilized_CD34_Primary_Cells_Female                               0.000000
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.000000
# Ovary                                                             0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    0.882149
# H1_Cell_Line                                                      0.000000
# Fetal_Brain_Female                                                0.000000
# Small_Intestine                                                   0.000000
#
# position                                          chr1-100014419-100015173  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.000000
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.000000
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.000000
# Breast_vHMEC                                                      0.000000
# H1_Derived_Mesenchymal_Stem_Cells                                 0.522140
# Fetal_Intestine_Small                                             0.000000
# Fetal_Intestine_Large                                             0.000000
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.000000
# Psoas_Muscle                                                      0.000000
# Gastric                                                           0.705144
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.672568
# Pancreas                                                          0.000000
# Mobilized_CD34_Primary_Cells_Female                               0.000000
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.000000
# Ovary                                                             0.879505
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    0.832427
# H1_Cell_Line                                                      0.000000
# Fetal_Brain_Female                                                1.000000
# Small_Intestine                                                   0.000000
#
# position                                          chr1-100023083-100024439  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.000000
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.672303
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.000000
# Breast_vHMEC                                                      0.697993
# H1_Derived_Mesenchymal_Stem_Cells                                 0.519866
# Fetal_Intestine_Small                                             0.000000
# Fetal_Intestine_Large                                             0.000000
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.000000
# Psoas_Muscle                                                      0.000000
# Gastric                                                           0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.908542
# Pancreas                                                          0.000000
# Mobilized_CD34_Primary_Cells_Female                               0.000000
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.572245
# Ovary                                                             0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    1.000000
# H1_Cell_Line                                                      0.000000
# Fetal_Brain_Female                                                0.000000
# Small_Intestine                                                   0.000000
#
# position                                          chr1-10002354-10004062  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                      0.873887
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                0.765626
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                      0.622360
# Breast_vHMEC                                                    0.769016
# H1_Derived_Mesenchymal_Stem_Cells                               0.813770
# Fetal_Intestine_Small                                           0.768473
# Fetal_Intestine_Large                                           0.786875
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                   0.846682
# Psoas_Muscle                                                    0.869609
# Gastric                                                         0.697079
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                  1.000000
# Pancreas                                                        0.812906
# Mobilized_CD34_Primary_Cells_Female                             0.947165
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                  0.895560
# Ovary                                                           0.797715
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                  0.893911
# H1_Cell_Line                                                    0.736243
# Fetal_Brain_Female                                              0.882294
# Small_Intestine                                                 0.795874
#
# position                                          chr1-100035927-100036679  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.000000
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.000000
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.000000
# Breast_vHMEC                                                      0.000000
# H1_Derived_Mesenchymal_Stem_Cells                                 0.000000
# Fetal_Intestine_Small                                             0.000000
# Fetal_Intestine_Large                                             0.000000
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.000000
# Psoas_Muscle                                                      0.748278
# Gastric                                                           0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.807653
# Pancreas                                                          0.000000
# Mobilized_CD34_Primary_Cells_Female                               0.000000
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.874646
# Ovary                                                             0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    0.665237
# H1_Cell_Line                                                      0.000000
# Fetal_Brain_Female                                                1.000000
# Small_Intestine                                                   0.000000
#
# position                                          chr1-100045144-100046572  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.000000
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.888493
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.444284
# Breast_vHMEC                                                      1.000000
# H1_Derived_Mesenchymal_Stem_Cells                                 0.000000
# Fetal_Intestine_Small                                             0.000000
# Fetal_Intestine_Large                                             0.000000
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.000000
# Psoas_Muscle                                                      0.000000
# Gastric                                                           0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.000000
# Pancreas                                                          0.000000
# Mobilized_CD34_Primary_Cells_Female                               0.000000
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.837676
# Ovary                                                             0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    0.000000
# H1_Cell_Line                                                      0.000000
# Fetal_Brain_Female                                                0.614794
# Small_Intestine                                                   0.000000
#
# position                                          chr1-100056080-100057113  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.000000
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.750566
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.000000
# Breast_vHMEC                                                      0.963854
# H1_Derived_Mesenchymal_Stem_Cells                                 0.598469
# Fetal_Intestine_Small                                             0.000000
# Fetal_Intestine_Large                                             0.000000
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.000000
# Psoas_Muscle                                                      0.659742
# Gastric                                                           0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.885793
# Pancreas                                                          0.000000
# Mobilized_CD34_Primary_Cells_Female                               0.000000
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.635305
# Ovary                                                             0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    1.000000
# H1_Cell_Line                                                      0.000000
# Fetal_Brain_Female                                                0.877952
# Small_Intestine                                                   0.000000
#
# position                                          chr1-100064269-100067014  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.606913
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.719029
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.627059
# Breast_vHMEC                                                      0.607513
# H1_Derived_Mesenchymal_Stem_Cells                                 0.971144
# Fetal_Intestine_Small                                             0.000000
# Fetal_Intestine_Large                                             0.000000
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.548052
# Psoas_Muscle                                                      0.464115
# Gastric                                                           0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.709905
# Pancreas                                                          0.000000
# Mobilized_CD34_Primary_Cells_Female                               0.000000
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.723937
# Ovary                                                             0.684594
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    1.000000
# H1_Cell_Line                                                      0.483261
# Fetal_Brain_Female                                                0.593380
# Small_Intestine                                                   0.000000
#
# position                                          chr1-10010120-10011675  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                      0.715858
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                0.662114
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                      0.470040
# Breast_vHMEC                                                    0.533778
# H1_Derived_Mesenchymal_Stem_Cells                               0.740258
# Fetal_Intestine_Small                                           0.657892
# Fetal_Intestine_Large                                           0.450724
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                   0.701233
# Psoas_Muscle                                                    0.563889
# Gastric                                                         0.638925
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                  0.881355
# Pancreas                                                        0.725158
# Mobilized_CD34_Primary_Cells_Female                             1.000000
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                  0.735616
# Ovary                                                           0.712376
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                  0.833048
# H1_Cell_Line                                                    0.774304
# Fetal_Brain_Female                                              0.830634
# Small_Intestine                                                 0.654560
#
# position                                          chr1-100109783-100114190  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.656221
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.755773
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.595829
# Breast_vHMEC                                                      1.000000
# H1_Derived_Mesenchymal_Stem_Cells                                 0.553962
# Fetal_Intestine_Small                                             0.000000
# Fetal_Intestine_Large                                             0.000000
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.000000
# Psoas_Muscle                                                      0.963133
# Gastric                                                           0.750677
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.721720
# Pancreas                                                          0.681333
# Mobilized_CD34_Primary_Cells_Female                               0.000000
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.000000
# Ovary                                                             0.549646
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    0.677937
# H1_Cell_Line                                                      0.632958
# Fetal_Brain_Female                                                0.896524
# Small_Intestine                                                   0.372496
#
# position                                                    ...             \
# tissue                                                      ...
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                  ...
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02            ...
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                  ...
# Breast_vHMEC                                                ...
# H1_Derived_Mesenchymal_Stem_Cells                           ...
# Fetal_Intestine_Small                                       ...
# Fetal_Intestine_Large                                       ...
# H1_Derived_Neuronal_Progenitor_Cultured_Cells               ...
# Psoas_Muscle                                                ...
# Gastric                                                     ...
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01              ...
# Pancreas                                                    ...
# Mobilized_CD34_Primary_Cells_Female                         ...
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01              ...
# Ovary                                                       ...
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02              ...
# H1_Cell_Line                                                ...
# Fetal_Brain_Female                                          ...
# Small_Intestine                                             ...
#
# position                                          chr1-110518335-110520863  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.000000
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.764963
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.605684
# Breast_vHMEC                                                      0.779467
# H1_Derived_Mesenchymal_Stem_Cells                                 0.621695
# Fetal_Intestine_Small                                             0.000000
# Fetal_Intestine_Large                                             0.000000
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.000000
# Psoas_Muscle                                                      0.960624
# Gastric                                                           0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.872469
# Pancreas                                                          0.518964
# Mobilized_CD34_Primary_Cells_Female                               0.000000
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.959978
# Ovary                                                             0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    1.000000
# H1_Cell_Line                                                      0.000000
# Fetal_Brain_Female                                                0.000000
# Small_Intestine                                                   0.000000
#
# position                                          chr1-110521191-110523948  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.462965
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.586306
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.742073
# Breast_vHMEC                                                      0.703276
# H1_Derived_Mesenchymal_Stem_Cells                                 0.766537
# Fetal_Intestine_Small                                             0.464682
# Fetal_Intestine_Large                                             0.415640
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.000000
# Psoas_Muscle                                                      0.772163
# Gastric                                                           0.754702
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.894810
# Pancreas                                                          0.654079
# Mobilized_CD34_Primary_Cells_Female                               0.534242
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.486956
# Ovary                                                             0.458968
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    1.000000
# H1_Cell_Line                                                      0.583595
# Fetal_Brain_Female                                                0.000000
# Small_Intestine                                                   0.802101
#
# position                                          chr1-110525979-110530178  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.787131
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.630390
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.711262
# Breast_vHMEC                                                      0.737806
# H1_Derived_Mesenchymal_Stem_Cells                                 0.799247
# Fetal_Intestine_Small                                             0.868285
# Fetal_Intestine_Large                                             0.911298
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.897637
# Psoas_Muscle                                                      0.810181
# Gastric                                                           0.767555
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.903662
# Pancreas                                                          0.967228
# Mobilized_CD34_Primary_Cells_Female                               0.888272
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.862059
# Ovary                                                             0.936976
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    0.941886
# H1_Cell_Line                                                      0.770855
# Fetal_Brain_Female                                                0.929638
# Small_Intestine                                                   1.000000
#
# position                                          chr1-110536565-110536851  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.000000
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.000000
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.000000
# Breast_vHMEC                                                      0.517460
# H1_Derived_Mesenchymal_Stem_Cells                                 0.000000
# Fetal_Intestine_Small                                             0.000000
# Fetal_Intestine_Large                                             0.000000
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.000000
# Psoas_Muscle                                                      0.000000
# Gastric                                                           0.752840
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.946899
# Pancreas                                                          0.570043
# Mobilized_CD34_Primary_Cells_Female                               0.000000
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.000000
# Ovary                                                             0.744271
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    0.955424
# H1_Cell_Line                                                      0.000000
# Fetal_Brain_Female                                                1.000000
# Small_Intestine                                                   0.691987
#
# position                                          chr1-110538791-110540771  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.000000
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.000000
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.775274
# Breast_vHMEC                                                      0.000000
# H1_Derived_Mesenchymal_Stem_Cells                                 0.787353
# Fetal_Intestine_Small                                             0.000000
# Fetal_Intestine_Large                                             0.000000
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.000000
# Psoas_Muscle                                                      0.412506
# Gastric                                                           0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.729741
# Pancreas                                                          0.000000
# Mobilized_CD34_Primary_Cells_Female                               0.000000
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    1.000000
# Ovary                                                             0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    0.570591
# H1_Cell_Line                                                      0.000000
# Fetal_Brain_Female                                                0.000000
# Small_Intestine                                                   0.000000
#
# position                                          chr1-110546188-110547474  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.890835
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.917945
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.810631
# Breast_vHMEC                                                      0.967712
# H1_Derived_Mesenchymal_Stem_Cells                                 0.924783
# Fetal_Intestine_Small                                             0.667278
# Fetal_Intestine_Large                                             0.840901
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.577373
# Psoas_Muscle                                                      0.858800
# Gastric                                                           0.843020
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.903623
# Pancreas                                                          0.875411
# Mobilized_CD34_Primary_Cells_Female                               0.435719
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.586033
# Ovary                                                             0.686529
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    0.965485
# H1_Cell_Line                                                      0.573186
# Fetal_Brain_Female                                                0.000000
# Small_Intestine                                                   1.000000
#
# position                                          chr1-110553934-110555240  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.572028
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.587950
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.799380
# Breast_vHMEC                                                      0.743348
# H1_Derived_Mesenchymal_Stem_Cells                                 0.805039
# Fetal_Intestine_Small                                             0.681920
# Fetal_Intestine_Large                                             0.509309
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.000000
# Psoas_Muscle                                                      0.467869
# Gastric                                                           0.542439
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.793717
# Pancreas                                                          0.506365
# Mobilized_CD34_Primary_Cells_Female                               0.891250
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    1.000000
# Ovary                                                             0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    0.799544
# H1_Cell_Line                                                      0.635227
# Fetal_Brain_Female                                                0.000000
# Small_Intestine                                                   0.735413
#
# position                                          chr1-110572176-110573476  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.968003
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.675156
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.757491
# Breast_vHMEC                                                      0.602562
# H1_Derived_Mesenchymal_Stem_Cells                                 0.919566
# Fetal_Intestine_Small                                             0.710761
# Fetal_Intestine_Large                                             0.685165
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.827973
# Psoas_Muscle                                                      0.590649
# Gastric                                                           0.679703
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    1.000000
# Pancreas                                                          0.815751
# Mobilized_CD34_Primary_Cells_Female                               0.941557
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.891531
# Ovary                                                             0.926338
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    0.927064
# H1_Cell_Line                                                      0.902871
# Fetal_Brain_Female                                                0.952071
# Small_Intestine                                                   0.814895
#
# position                                          chr1-110573682-110574283  \
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.595887
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.583696
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.000000
# Breast_vHMEC                                                      0.000000
# H1_Derived_Mesenchymal_Stem_Cells                                 0.590259
# Fetal_Intestine_Small                                             0.000000
# Fetal_Intestine_Large                                             0.000000
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.000000
# Psoas_Muscle                                                      0.000000
# Gastric                                                           0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.651498
# Pancreas                                                          0.000000
# Mobilized_CD34_Primary_Cells_Female                               0.000000
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.000000
# Ovary                                                             0.000000
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    1.000000
# H1_Cell_Line                                                      0.602607
# Fetal_Brain_Female                                                0.965976
# Small_Intestine                                                   0.898875
#
# position                                          chr1-110576423-110578345
# tissue
# H1_BMP4_Derived_Mesendoderm_Cultured_Cells                        0.749140
# Penis_Foreskin_Keratinocyte_Primary_Cells_skin02                  0.767934
# H1_BMP4_Derived_Trophoblast_Cultured_Cells                        0.564568
# Breast_vHMEC                                                      0.768179
# H1_Derived_Mesenchymal_Stem_Cells                                 0.902224
# Fetal_Intestine_Small                                             0.720148
# Fetal_Intestine_Large                                             0.710948
# H1_Derived_Neuronal_Progenitor_Cultured_Cells                     0.762374
# Psoas_Muscle                                                      0.799403
# Gastric                                                           0.677673
# Penis_Foreskin_Fibroblast_Primary_Cells_skin01                    0.829395
# Pancreas                                                          0.790118
# Mobilized_CD34_Primary_Cells_Female                               0.917530
# Penis_Foreskin_Melanocyte_Primary_Cells_skin01                    0.736283
# Ovary                                                             0.810581
# Penis_Foreskin_Fibroblast_Primary_Cells_skin02                    1.000000
# H1_Cell_Line                                                      0.768191
# Fetal_Brain_Female                                                0.849349
# Small_Intestine                                                   0.752353
#
# [19 rows x 500 columns]

# %% [markdown]
# ## MLPC classification method

# %%
#for loop to run 500 sites in 
accuracy_list = [] 
for i in list(samples.columns):
    RNA_list = list(find_gene_list(i, df_gene_info, 1000000))
    #define input dataframe and output series
    input = df_rna[RNA_list]
    output = samples[i]
    output[output != 0] = 1
    #randomly split into training (80%) and testing (20%) dataset
    train_x,test_x=train_test_split(input,test_size=0.2)
    train_y = output.loc[train_x.index]
    test_y = output.loc[test_x.index]
    #train the model using MLPC method
    MLPC = MLPClassifier(solver='lbfgs', alpha=1e-5,
                         hidden_layer_sizes=(5, 2), random_state=1)
    MLPC.fit(train_x,train_y)
    MLPC.predict(test_x)
    #calculate the accuracy
    correct = 0
    pred_y = list(MLPC.predict(test_x))
    for i in range(len(test_x)):
        if pred_y[i] == test_y[i]:
            correct += 1
    accuracy =repr((correct/float(len(test_x))) * 100) + "%"
    accuracy_list.append(accuracy)

# %%
accuracy_list
# Out:
# ['50.0%',
#  '75.0%',
#  '25.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '25.0%',
#  '75.0%',
#  '25.0%',
#  '75.0%',
#  '50.0%',
#  '25.0%',
#  '75.0%',
#  '100.0%',
#  '75.0%',
#  '25.0%',
#  '75.0%',
#  '100.0%',
#  '25.0%',
#  '50.0%',
#  '50.0%',
#  '100.0%',
#  '25.0%',
#  '100.0%',
#  '50.0%',
#  '100.0%',
#  '25.0%',
#  '100.0%',
#  '25.0%',
#  '50.0%',
#  '50.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '50.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '75.0%',
#  '100.0%',
#  '25.0%',
#  '75.0%',
#  '100.0%',
#  '100.0%',
#  '50.0%',
#  '100.0%',
#  '100.0%',
#  '50.0%',
#  '50.0%',
#  '75.0%',
#  '25.0%',
#  '50.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '50.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '75.0%',
#  '50.0%',
#  '50.0%',
#  '75.0%',
#  '50.0%',
#  '25.0%',
#  '100.0%',
#  '25.0%',
#  '50.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '50.0%',
#  '75.0%',
#  '100.0%',
#  '50.0%',
#  '100.0%',
#  '0.0%',
#  '25.0%',
#  '75.0%',
#  '25.0%',
#  '50.0%',
#  '25.0%',
#  '25.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '25.0%',
#  '50.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '25.0%',
#  '100.0%',
#  '25.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '0.0%',
#  '75.0%',
#  '25.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '50.0%',
#  '100.0%',
#  '50.0%',
#  '50.0%',
#  '50.0%',
#  '50.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '50.0%',
#  '100.0%',
#  '75.0%',
#  '50.0%',
#  '75.0%',
#  '100.0%',
#  '50.0%',
#  '25.0%',
#  '100.0%',
#  '50.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '50.0%',
#  '50.0%',
#  '75.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '25.0%',
#  '50.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '50.0%',
#  '25.0%',
#  '75.0%',
#  '100.0%',
#  '50.0%',
#  '75.0%',
#  '50.0%',
#  '25.0%',
#  '25.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '25.0%',
#  '50.0%',
#  '50.0%',
#  '50.0%',
#  '50.0%',
#  '50.0%',
#  '25.0%',
#  '50.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '75.0%',
#  '25.0%',
#  '25.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '50.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '50.0%',
#  '25.0%',
#  '50.0%',
#  '100.0%',
#  '25.0%',
#  '100.0%',
#  '50.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '50.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '50.0%',
#  '25.0%',
#  '75.0%',
#  '50.0%',
#  '50.0%',
#  '50.0%',
#  '50.0%',
#  '25.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '50.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '25.0%',
#  '100.0%',
#  '50.0%',
#  '50.0%',
#  '25.0%',
#  '75.0%',
#  '50.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '25.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '50.0%',
#  '75.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '50.0%',
#  '50.0%',
#  '100.0%',
#  '50.0%',
#  '50.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '50.0%',
#  '50.0%',
#  '100.0%',
#  '25.0%',
#  '50.0%',
#  '0.0%',
#  '50.0%',
#  '75.0%',
#  '100.0%',
#  '25.0%',
#  '100.0%',
#  '50.0%',
#  '50.0%',
#  '25.0%',
#  '100.0%',
#  '50.0%',
#  '50.0%',
#  '25.0%',
#  '25.0%',
#  '75.0%',
#  '50.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '25.0%',
#  '50.0%',
#  '75.0%',
#  '50.0%',
#  '25.0%',
#  '25.0%',
#  '25.0%',
#  '100.0%',
#  '25.0%',
#  '75.0%',
#  '100.0%',
#  '50.0%',
#  '100.0%',
#  '25.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '75.0%',
#  '100.0%',
#  '100.0%',
#  '50.0%',
#  '25.0%',
#  '100.0%',
#  '75.0%',
#  '100.0%',
#  '25.0%',
#  '50.0%',
#  '0.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '25.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '50.0%',
#  '75.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '25.0%',
#  '25.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '100.0%',
#  '100.0%',
#  '50.0%',
#  '100.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '50.0%',
#  '75.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '100.0%',
#  '75.0%',
#  '50.0%',
#  '25.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '25.0%',
#  '100.0%',
#  '75.0%',
#  '50.0%',
#  '75.0%',
#  '100.0%',
#  '25.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '25.0%',
#  '50.0%',
#  '75.0%',
#  '25.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '25.0%',
#  '25.0%',
#  '50.0%',
#  '75.0%',
#  '100.0%',
#  '0.0%',
#  '100.0%',
#  '75.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '25.0%',
#  '100.0%',
#  '50.0%',
#  '100.0%',
#  '75.0%',
#  '50.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '50.0%',
#  '75.0%',
#  '75.0%',
#  '75.0%',
#  '100.0%',
#  '100.0%',
#  '100.0%',
#  '50.0%',
#  '100.0%',
#  '75.0%',
#  '50.0%',
#  '50.0%',
#  '75.0%',
#  '50.0%',
#  '50.0%',
#  '75.0%',
#  '25.0%',
#  '75.0%',
#  '25.0%',
#  '50.0%',
#  '25.0%',
#  '75.0%',
#  '25.0%',
#  '75.0%',
#  '25.0%',
#  '25.0%',
#  '75.0%',
#  '50.0%',
#  '75.0%',
#  '100.0%',
#  '100.0%',
#  '50.0%',
#  '50.0%',
#  '50.0%',
#  '50.0%',
#  '75.0%',
#  '100.0%',
#  '50.0%',
#  '50.0%',
#  '100.0%',
#  '25.0%',
#  '100.0%',
#  '100.0%',
#  '75.0%',
#  '100.0%',
#  '75.0%',
#  '50.0%',
#  '100.0%',
#  '50.0%',
#  '100.0%',
#  '75.0%',
#  '100.0%']

# %%
#calculate the average accuracy for different classification methods
sum = 0
for i in accuracy_list:
    sum += float((i.split('%')[0]))
avg_accuracy = repr(sum/len(accuracy_list))+"%"
avg_accuracy
# Out:
# '68.5%'

# %% [markdown]
# ## Decision Trees classification method

# %%
#Decision Trees
from sklearn import tree

# %%
#for loop to run 500 sites in 
accuracy_list = [] 
for i in list(samples.columns):
    RNA_list = list(find_gene_list(i, df_gene_info, 1000000))
    #define input dataframe and output series
    input = df_rna[RNA_list]
    output = samples[i]
    output[output != 0] = 1
    #randomly split into training (80%) and testing (20%) dataset
    train_x,test_x=train_test_split(input,test_size=0.2)
    train_y = output.loc[train_x.index]
    test_y = output.loc[test_x.index]
    #train the model using Decision Tree Classifier method
    DTC = tree.DecisionTreeClassifier()
    DTC.fit(train_x,train_y)
    DTC.predict(test_x)
    #calculate the accuracy
    correct = 0
    pred_y = list(DTC.predict(test_x))
    for i in range(len(test_x)):
        if pred_y[i] == test_y[i]:
            correct += 1
    accuracy =repr((correct/float(len(test_x))) * 100) + "%"
    accuracy_list.append(accuracy)

# %%
#calculate the average accuracy for different classification methods
sum = 0
for i in accuracy_list:
    sum += float((i.split('%')[0]))
avg_accuracy = repr(sum/len(accuracy_list))+"%"
avg_accuracy
# Out:
# '66.6%'
